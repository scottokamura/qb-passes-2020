# %%
import requests
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
def corr_(df, n = 0.85, x = 1):
    '''
    
    Input - df: dataframe
            n: lower limit of correlation
            x: upper limit of correlation
            
    Output - dataframe with correlated pairs and correlation values
    
    '''
    df_cc=df.corr().abs().stack().reset_index().sort_values(0, ascending=False)
    df_cc['pairs'] = list(zip(df_cc.level_0, df_cc.level_1))
    df_cc.set_index(['pairs'], inplace = True)
    df_cc.drop(columns=['level_1', 'level_0'], inplace = True)
    df_cc.columns = ['cc']
    df_cc.drop_duplicates(inplace=True)
    
    return df_cc[(df_cc['cc'] > n) & (df_cc['cc'] < x)]

def find_outlier(df, feature):
    q1 = df[feature].quantile(0.25)
    q3 = df[feature].quantile(0.75)
    iqr = q3 - q1
    lower = q1-(iqr*1.5)
    upper = q3+(iqr*1.5)
    return iqr, lower, upper

def convert_game_clock(row):
    raw_game_clock = row['clock']
    quarter = int(row['quarter'])
    game_clock = raw_game_clock.split(':')
    minutes = game_clock[0]
    seconds = game_clock[1]
    seconds_left_in_quarter = int(seconds) + (int(minutes) * 60)
    
    if quarter == 1 or quarter == 3:
        return seconds_left_in_quarter + 900
    elif quarter == 2 or quarter == 4:
        return seconds_left_in_quarter
    
    
def make_table(data, groups, agg=['sum', 'count']):

    data = data.groupby(groups).agg(agg)['complete']
    data['pct'] = data['sum']/data['count']
    return data

# %% [markdown]
# # SportRadar

# %%
# establish connection to sportradar api
# need to enter private api_key
import http.client

api_key = api_key
conn = http.client.HTTPSConnection("api.sportradar.us")
conn.request("GET", f"/nfl/official/trial/v6/en/games/0e00303b-ee60-4cf4-ad68-48efbe53901d/pbp.json?api_key={api_key}")

res = conn.getresponse()
data = res.read()
json_object = json.loads(data)

# %%
# unpacking json object data 
df = pd.json_normalize(json_object, record_path=['periods'], 
                       meta=[['summary', 'season', 'year']], errors='ignore')
season = df['summary.season.year'][0]

# %%
# unpacking plays by quarter and combining all drives
q1 = pd.json_normalize(df['pbp'][0])
q2 = pd.json_normalize(df['pbp'][1])
q3 = pd.json_normalize(df['pbp'][2])
q4 = pd.json_normalize(df['pbp'][3])
quarters = [q1, q2, q3, q4]

drives = pd.concat(quarters, ignore_index=True)
drives = drives.loc[drives['type'] == 'drive']

# %%
# filtering pass plays from all plays
plays = []
for i, row in drives.iterrows():
    play = row['events']
    for n in play:
        plays.append(n)

# some pass plays missing pass_route data
passing_areas = ['Flat', 'Underneath Screen', 'WR Screen',
                 'Comeback', 'Curl', 'Cross', 'Go', 'Slant', 'Out']
plays = pd.DataFrame(plays)

# include pass_plays that include pass_route
pass_plays = plays.loc[(plays['play_type'] == 'pass') & (plays['pass_route'].isin(passing_areas))]
pass_plays.reset_index(inplace=True, drop=True)

# %% [markdown]
# ### Sanity Check

# %%
# investigating pass plays that did not include pass_route data
penalties = plays.loc[(plays['play_type'] == 'pass') & ~(plays['pass_route'].isin(passing_areas))]

# %%
# offensive pass interference, noplay
penalties.loc[73]['details']
# Out:
# [{'category': 'pass_completion',
#   'description': 'J.Garoppolo pass deep right complete to KC 21.',
#   'sequence': 1,
#   'direction': 'deep right',
#   'yards': 42,
#   'start_location': {'alias': 'SF', 'yardline': 45},
#   'end_location': {'alias': 'KC', 'yardline': 21},
#   'players': [{'id': '42de9d1d-0352-460b-9172-9452414fd7fd',
#     'name': 'Jimmy Garoppolo',
#     'jersey': '10',
#     'position': 'QB',
#     'sr_id': 'sr:player:828285',
#     'role': 'pass'}]},
#  {'category': 'pass_reception',
#   'description': 'Catch made by G.Kittle at KC 21. Gain of 42 yards.',
#   'sequence': 2,
#   'yards': 42,
#   'result': 'tackled',
#   'start_location': {'alias': 'KC', 'yardline': 21},
#   'end_location': {'alias': 'KC', 'yardline': 13},
#   'players': [{'id': '2ada91b0-036e-454f-83c3-6d939ff584a9',
#     'name': 'George Kittle',
#     'jersey': '85',
#     'position': 'TE',
#     'sr_id': 'sr:player:1130029',
#     'role': 'catch'}]},
#  {'category': 'tackle',
#   'description': 'Tackled by D.Sorensen at KC 13.',
#   'sequence': 3,
#   'result': 'tackled',
#   'start_location': {'alias': 'KC', 'yardline': 13},
#   'end_location': {'alias': 'KC', 'yardline': 13},
#   'players': [{'id': 'd1e46e40-5e8c-4b5a-ae03-5d0093b98633',
#     'name': 'Daniel Sorensen',
#     'jersey': '49',
#     'position': 'S',
#     'sr_id': 'sr:player:855646',
#     'role': 'tackle'}]},
#  {'category': 'penalty',
#   'description': 'PENALTY on SF-G.Kittle, Offensive Pass Interference, 10 yards, Accepted.',
#   'sequence': 4,
#   'start_location': {'alias': 'KC', 'yardline': 13},
#   'end_location': {'alias': 'SF', 'yardline': 35},
#   'penalty': {'description': 'Offensive Pass Interference',
#    'no_play': True,
#    'result': 'Accepted',
#    'yards': 10,
#    'team': {'id': 'f0e724b0-4cbf-495a-be47-013907608da9',
#     'name': '49ers',
#     'market': 'San Francisco',
#     'alias': 'SF',
#     'sr_id': 'sr:competitor:4389'}},
#   'players': [{'id': '2ada91b0-036e-454f-83c3-6d939ff584a9',
#     'name': 'George Kittle',
#     'jersey': '85',
#     'position': 'TE',
#     'sr_id': 'sr:player:1130029',
#     'role': 'penalty'}]}]

# %%
# rollout at end of half, not counted towards stats
penalties.loc[171]
# Out:
# type                                                                play
# id                                  88eceb25-606e-4572-9229-d8404190f3af
# sequence                                                          4091.0
# reference                                                           4091
# clock                                                              00:05
# home_points                                                         31.0
# away_points                                                         20.0
# play_type                                                           pass
# play_clock                                                          23.0
# wall_clock                                     2020-02-03T03:10:28+00:00
# description            (:05) (Shotgun) 15-P.Mahomes pass incomplete d...
# alt_description        (:05) (Shotgun) P.Mahomes pass incomplete deep...
# fake_punt                                                          False
# fake_field_goal                                                    False
# screen_pass                                                        False
# hash_mark                                                     Right Hash
# play_action                                                        False
# run_pass_option                                                    False
# created_at                                     2020-02-03T03:10:49+00:00
# updated_at                                     2021-01-06T15:21:11+00:00
# start_situation        {'clock': '00:05', 'down': 4, 'yfd': 25, 'poss...
# end_situation          {'clock': '00:00', 'down': 1, 'yfd': 10, 'poss...
# statistics             [{'stat_type': 'pass', 'attempt': 1, 'complete...
# details                [{'category': 'pass_incompletion', 'descriptio...
# men_in_box                                                           7.0
# blitz                                                               True
# play_direction                                                     Right
# left_tightends                                                       0.0
# right_tightends                                                      2.0
# qb_at_snap                                                       Shotgun
# huddle                                                            Huddle
# running_lane                                                         NaN
# players_rushed                                                       5.0
# pocket_location                                            Rollout Right
# pass_route                                                           NaN
# scoring_play                                                         NaN
# scoring_description                                                  NaN
# score                                                                NaN
# goaltogo                                                             NaN
# event_type                                                           NaN
# team                                                                 NaN
# Name: 171, dtype: object

# %%
# getting stats from pass_plays
passing_stats = []
for i, item in pass_plays['statistics'].iteritems():
    stats = pd.Series(item[0])
    passing_stats.append(stats)
    
# getting additional details from pass_plays    
passing_details = []
for i, item in pass_plays['details'].iteritems():
    details = pd.Series(item[0])
    passing_details.append(details)
    

df = pd.DataFrame(passing_stats)
dfi = pd.DataFrame(passing_details)

df = pd.concat([df,dfi], axis=1)

# additional data in pass_plays
additional_columns = ['hash_mark', 'play_action', 'run_pass_option', 'blitz',
                      'qb_at_snap', 'players_rushed', 'pocket_location', 'pass_route']

df = df.merge(pass_plays[additional_columns], left_index=True, right_index=True)
df['season'] = season

# %%
# adding name/team for each qb
names = []
teams = []
for i, row in df.iterrows():

    name = row['player']['name']
    names.append(name)
    team = row['team']['alias']
    teams.append(team)
df['name'] = names
df['team'] = teams

# %% [markdown]
# ## Cleaning Data Columns

# %%
df.shape
# Out:
# (70, 37)

# %%
# redundant data
dropping = ['player', 'description', 'players',
            'stat_type', 'attempt', 'category']
df.drop(columns=dropping, inplace=True)

# %%
# removing duplicate columns
df = df.loc[:, ~df.columns.duplicated()]

# %%
# reordering columns
name_col = df.pop('name')
team_col = df.pop('team')
df.insert(0, 'name', name_col)
df.insert(1, 'team', team_col)

# %%
# export data
df.to_csv('./Data/first_game.csv')

# %% [markdown]
# ---
# ## End of Pass Data from 1 Game
# ***

# %% [markdown]
# ## Getting Game ID from Schedule

# %%
api_key = api_key
conn = http.client.HTTPSConnection("api.sportradar.us")

# 2020 schedule
conn.request("GET", f"/nfl/official/trial/v6/en/games/2020/REG/schedule.json?api_key={api_key}")
res = conn.getresponse()
data = res.read()

# %%
# convert schedule data to df
json_object = json.loads(data)
sch = pd.DataFrame(json_object)
# Out:
# {'id': '2eec467f-9ce1-484c-b58f-e11615bede68',
#  'year': 2020,
#  'type': 'REG',
#  'name': 'REG',
#  'weeks': [{'id': 'fd51f745-b7eb-4c01-8550-d9095aa5407d',
#    'sequence': 1,
#    'title': '1',
#    'games': [{'id': '018556f9-1977-4a0b-8244-20cad15df9a4',
#      'status': 'closed',
#      'reference': '58178',
#      'number': 11,
#      'scheduled': '2020-09-13T20:05:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Partly Cloudy Temp: 83 F, Humidity: 56%, Wind: NW 6 mph, gusts to 8 mph',
#      'sr_id': 'sr:match:21980371',
#      'venue': {'id': 'b87a1595-d3c8-48ea-8a53-0aab6378a64a',
#       'name': 'Paul Brown Stadium',
#       'city': 'Cincinnati',
#       'state': 'OH',
#       'country': 'USA',
#       'zip': '45202',
#       'address': 'One Paul Brown Stadium',
#       'capacity': 65515,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8175',
#       'location': {'lat': '39.095413', 'lng': '-84.516204'}},
#      'home': {'id': 'ad4ae08f-d808-42d5-a1e6-e9bc4e34d123',
#       'name': 'Cincinnati Bengals',
#       'alias': 'CIN',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4416'},
#      'away': {'id': '1f6dcffb-9823-43cd-9ff4-e7a8466749b5',
#       'name': 'Los Angeles Chargers',
#       'alias': 'LAC',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4429'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 13,
#       'away_points': 16,
#       'periods': [{'period_type': 'quarter',
#         'id': 'e8cc686b-0ded-4e9e-b9c0-b462a6884ebb',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '978b2e9c-617b-4970-990c-1077facdda30',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 0,
#         'away_points': 6},
#        {'period_type': 'quarter',
#         'id': 'a0d913ec-dfa4-4f79-a76c-ab74facda9d8',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 6,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '3547ebc5-9ea0-4e2f-b414-33fee3ae4012',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 10}]}},
#     {'id': '10339048-8c6b-43c7-ae7c-d68cf44417d3',
#      'status': 'closed',
#      'reference': '58183',
#      'number': 16,
#      'scheduled': '2020-09-15T02:20:00+00:00',
#      'attendance': 0,
#      'utc_offset': -7,
#      'entry_mode': 'INGEST',
#      'weather': 'Mostly Clear Temp: 79 F, Humidity: 14%, Wind: South East 10 mph',
#      'sr_id': 'sr:match:21980381',
#      'venue': {'id': '6589e61d-ef1e-4e30-91b5-9acd2072b8a0',
#       'name': 'Empower Field at Mile High',
#       'city': 'Denver',
#       'state': 'CO',
#       'country': 'USA',
#       'zip': '80204',
#       'address': '1701 Mile High Stadium Circle',
#       'capacity': 76125,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:30961',
#       'location': {'lat': '39.743865', 'lng': '-105.020158'}},
#      'home': {'id': 'ce92bd47-93d5-4fe9-ada4-0fc681e6caa0',
#       'name': 'Denver Broncos',
#       'alias': 'DEN',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4418'},
#      'away': {'id': 'd26a1ca5-722d-4274-8f97-c92e49c96315',
#       'name': 'Tennessee Titans',
#       'alias': 'TEN',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:367364'},
#      'broadcast': {'network': 'ESPN', 'satellite': '206'},
#      'scoring': {'home_points': 14,
#       'away_points': 16,
#       'periods': [{'period_type': 'quarter',
#         'id': 'ccbf9e83-42e7-40bc-ad88-4428e8f5de7c',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'ba07b0b5-8b6c-40c4-aab1-4b94424e9b1d',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'be53492b-1f9a-4d8d-bdce-13c110b215a5',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '17b4371c-53c4-4186-8649-17b1c12346c1',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 9}]}},
#     {'id': '213b8eda-43d8-4e62-9951-ed4c605fca0d',
#      'status': 'closed',
#      'reference': '58175',
#      'number': 8,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'N/A (Indoors) Temp: Humidity: Wind:',
#      'sr_id': 'sr:match:21980357',
#      'venue': {'id': 'f5ff00d4-1ed8-4918-bf73-13d66d510f98',
#       'name': 'U.S. Bank Stadium',
#       'city': 'Minneapolis',
#       'state': 'MN',
#       'country': 'USA',
#       'zip': '55415',
#       'address': '900 S 5th Street',
#       'capacity': 66655,
#       'surface': 'artificial',
#       'roof_type': 'dome',
#       'sr_id': 'sr:venue:18423',
#       'location': {'lat': '44.973686', 'lng': '-93.257458'}},
#      'home': {'id': '33405046-04ee-4058-a950-d606f8c30852',
#       'name': 'Minnesota Vikings',
#       'alias': 'MIN',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4423'},
#      'away': {'id': 'a20471b4-a8d9-40c7-95ad-90cc30e46932',
#       'name': 'Green Bay Packers',
#       'alias': 'GB',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4420'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 34,
#       'away_points': 43,
#       'periods': [{'period_type': 'quarter',
#         'id': 'b52d8ce9-0e86-47ff-811a-0b3c49965292',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '40cfc58a-eea3-460c-ac9b-1d3cd66d9a3f',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 3,
#         'away_points': 19},
#        {'period_type': 'quarter',
#         'id': 'b7778a9d-3976-4c09-bef6-731dc2aae380',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'd7e9c248-8715-4907-8486-2f643f24f4ca',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 24,
#         'away_points': 14}]}},
#     {'id': '24734cde-bf1b-46e5-ad50-d61e47aeca26',
#      'status': 'closed',
#      'reference': '58174',
#      'number': 7,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 14100,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Partly Cloudy Temp: 80 F, Humidity: 85%, Wind: NNE 3MPH mph',
#      'sr_id': 'sr:match:21980359',
#      'venue': {'id': '4c5c036d-dd3d-4183-b595-71a43a97560f',
#       'name': 'TIAA Bank Field',
#       'city': 'Jacksonville',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '32202',
#       'address': 'One EverBank Field Drive',
#       'capacity': 69132,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8187',
#       'location': {'lat': '30.324027', 'lng': '-81.637239'}},
#      'home': {'id': 'f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de',
#       'name': 'Jacksonville Jaguars',
#       'alias': 'JAC',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4386'},
#      'away': {'id': '82cf9565-6eb9-4f01-bdbd-5aa0d472fcd9',
#       'name': 'Indianapolis Colts',
#       'alias': 'IND',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4421'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 27,
#       'away_points': 20,
#       'periods': [{'period_type': 'quarter',
#         'id': 'b2e79473-d034-4573-8576-5ccea145275c',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '2746d1cf-84e9-414c-a546-6036ed6267bd',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': 'a050dd65-e86f-4e74-8f3b-4cdeccdc5a7b',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 3,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '894aa380-ca60-49ec-9daf-18f3ab06c13c',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 10,
#         'away_points': 3}]}},
#     {'id': '5a5b0a83-1765-4729-b914-73ff7d4c4c89',
#      'status': 'closed',
#      'reference': '58172',
#      'number': 5,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Mostly Sunny Temp: 81 F, Humidity: 59%, Wind: N 5 mph',
#      'sr_id': 'sr:match:21980367',
#      'venue': {'id': '39be9ed4-3292-49ac-8699-a381de3a4969',
#       'name': 'Bank of America Stadium',
#       'city': 'Charlotte',
#       'state': 'NC',
#       'country': 'USA',
#       'zip': '28202',
#       'address': '800 South Mint Street',
#       'capacity': 75419,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8173',
#       'location': {'lat': '35.225937', 'lng': '-80.853133'}},
#      'home': {'id': 'f14bf5cc-9a82-4a38-bc15-d39f75ed5314',
#       'name': 'Carolina Panthers',
#       'alias': 'CAR',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4415'},
#      'away': {'id': '7d4fcc64-9cb5-4d1b-8e75-8a906d1e1576',
#       'name': 'Las Vegas Raiders',
#       'alias': 'LV',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4390'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 30,
#       'away_points': 34,
#       'periods': [{'period_type': 'quarter',
#         'id': '99af5624-74ad-42f8-b4ff-447377283f76',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 9,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '7e37628d-4c2e-45a7-9f03-843a74f16b7b',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 6,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '25e9f115-d87d-47e1-97bf-3c83b71aa27f',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': 'c356c564-f14e-4dd8-b313-2e5404ddf2b0',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 15,
#         'away_points': 7}]}},
#     {'id': '6b5b649e-7134-4e3e-a637-4347f32b732e',
#      'status': 'closed',
#      'reference': '58168',
#      'number': 1,
#      'scheduled': '2020-09-11T00:20:00+00:00',
#      'attendance': 15895,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 56 F, Humidity: 95%, Wind: N 7 mph',
#      'sr_id': 'sr:match:21980349',
#      'venue': {'id': '2ec4c411-dac2-403d-b091-6b6aa4a0a914',
#       'name': 'GEHA Field at Arrowhead Stadium',
#       'city': 'Kansas City',
#       'state': 'MO',
#       'country': 'USA',
#       'zip': '64129',
#       'address': 'One Arrowhead Drive',
#       'capacity': 76416,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8189',
#       'location': {'lat': '39.049019', 'lng': '-94.484140'}},
#      'home': {'id': '6680d28d-d4d2-49f6-aace-5292d3ec02c2',
#       'name': 'Kansas City Chiefs',
#       'alias': 'KC',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4422'},
#      'away': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#       'name': 'Houston Texans',
#       'alias': 'HOU',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4324'},
#      'broadcast': {'network': 'NBC'},
#      'scoring': {'home_points': 34,
#       'away_points': 20,
#       'periods': [{'period_type': 'quarter',
#         'id': '78daf1ea-1661-44ca-9ad2-1aaa14acde57',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'a4494780-f6c0-45cd-8f0b-f968926a38bf',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 17,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '36167bc3-f4ac-4e82-a173-496c3c20f4ed',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'ae1e07a9-a7f7-4823-a39d-4a0fcf7e95ab',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 10,
#         'away_points': 13}]}},
#     {'id': 'aa091a72-7c29-450b-8f21-cb3b77b36ac1',
#      'status': 'closed',
#      'reference': '58182',
#      'number': 15,
#      'scheduled': '2020-09-14T23:10:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Clear Temp: 71 F, Humidity: 44%, Wind: N 5 mph',
#      'sr_id': 'sr:match:21980379',
#      'venue': {'id': '5d4c85c7-d84e-4e10-bd6a-8a15ebecca5c',
#       'name': 'MetLife Stadium',
#       'city': 'East Rutherford',
#       'state': 'NJ',
#       'country': 'USA',
#       'zip': '07073',
#       'address': 'One MetLife Stadium Drive',
#       'capacity': 82500,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:1981',
#       'location': {'lat': '40.813611', 'lng': '-74.074444'}},
#      'home': {'id': '04aa1c9d-66da-489d-b16a-1dee3f2eec4d',
#       'name': 'New York Giants',
#       'alias': 'NYG',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4426'},
#      'away': {'id': 'cb2f9f1f-ac67-424e-9e72-1475cb0ed398',
#       'name': 'Pittsburgh Steelers',
#       'alias': 'PIT',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4345'},
#      'broadcast': {'network': 'ESPN', 'satellite': '206'},
#      'scoring': {'home_points': 16,
#       'away_points': 26,
#       'periods': [{'period_type': 'quarter',
#         'id': '0c06ef48-96f7-4878-92bf-2265e8b58f6a',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '1a644a21-83d7-4c07-9172-95dd2996a358',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 13},
#        {'period_type': 'quarter',
#         'id': '90bcad99-c256-42ac-82b0-287f9a5e89b3',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '5abd7568-0844-45bb-aa2c-cc089efcd5a8',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 6,
#         'away_points': 10}]}},
#     {'id': 'b1269b50-793b-4cd4-b127-04d39b13626d',
#      'status': 'closed',
#      'reference': '58181',
#      'number': 14,
#      'scheduled': '2020-09-14T00:20:00+00:00',
#      'attendance': 0,
#      'utc_offset': -8,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 72 F, Humidity: 64%, Wind: W 7 mph',
#      'sr_id': 'sr:match:21980377',
#      'venue': {'id': '790c1f04-73c6-4f6f-8b1e-78a62260be90',
#       'name': 'SoFi Stadium',
#       'city': 'Inglewood',
#       'state': 'CA',
#       'country': 'USA',
#       'zip': '90301',
#       'address': '1000 S Prairie Ave',
#       'capacity': 70240,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:52183',
#       'location': {'lat': '33.953536', 'lng': '-118.338734'}},
#      'home': {'id': '2eff2a03-54d4-46ba-890e-2bc3925548f3',
#       'name': 'Los Angeles Rams',
#       'alias': 'LA',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4387'},
#      'away': {'id': 'e627eec7-bbae-4fa4-8e73-8e1d6bc5c060',
#       'name': 'Dallas Cowboys',
#       'alias': 'DAL',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4392'},
#      'broadcast': {'network': 'NBC'},
#      'scoring': {'home_points': 20,
#       'away_points': 17,
#       'periods': [{'period_type': 'quarter',
#         'id': '5722b4ac-4704-418f-8e03-71dd18c78916',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'a959eef9-b618-40b9-b217-003fee612964',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 6,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': '8b6c91c1-83f8-43ef-aa75-fe08a9f727ef',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '71d12add-21d1-4d67-855b-342d69d89c67',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 0}]}},
#     {'id': 'b506a07c-4d7d-41e8-87f6-732c4f6d09fc',
#      'status': 'closed',
#      'reference': '58171',
#      'number': 4,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 67 F, Humidity: 93%, Wind: SSW 15 mph',
#      'sr_id': 'sr:match:21980365',
#      'venue': {'id': 'e9e0828e-37fc-4238-a317-49037577dd55',
#       'name': 'Highmark Stadium',
#       'city': 'Orchard Park',
#       'state': 'NY',
#       'country': 'USA',
#       'zip': '14127',
#       'address': 'One Bills Drive',
#       'capacity': 71608,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:20375',
#       'location': {'lat': '42.773826', 'lng': '-78.786589'}},
#      'home': {'id': '768c92aa-75ff-4a43-bcc0-f2798c2e1724',
#       'name': 'Buffalo Bills',
#       'alias': 'BUF',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4376'},
#      'away': {'id': '5fee86ae-74ab-4bdd-8416-42a9dd9964f3',
#       'name': 'New York Jets',
#       'alias': 'NYJ',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4427'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 27,
#       'away_points': 17,
#       'periods': [{'period_type': 'quarter',
#         'id': '7eeb1ba5-5252-4aab-b282-df8ef4510af4',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 14,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '69205543-9ddb-4a87-b973-80c989b78d4d',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'ec41379e-3e23-4e55-ba39-00c9038925ef',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '26d5ac9a-904f-4240-97db-3052e5faa0d9',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 6,
#         'away_points': 7}]}},
#     {'id': 'c2b24b1a-98c5-465c-8f83-b82e746b4fcf',
#      'status': 'closed',
#      'reference': '58169',
#      'number': 2,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Mostly Cloudy Temp: 80 F, Humidity: 69%, Wind: East 7 mph',
#      'sr_id': 'sr:match:21980351',
#      'venue': {'id': '1f2d393b-2291-4835-a412-0714966ea245',
#       'name': 'Mercedes-Benz Stadium',
#       'city': 'Atlanta',
#       'state': 'GA',
#       'country': 'USA',
#       'zip': '30313',
#       'address': '441 Martin Luther King Jr Drive NW',
#       'capacity': 71000,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:20343',
#       'location': {'lat': '33.757368', 'lng': '-84.401008'}},
#      'home': {'id': 'e6aa13a4-0055-48a9-bc41-be28dc106929',
#       'name': 'Atlanta Falcons',
#       'alias': 'ATL',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4393'},
#      'away': {'id': '3d08af9e-c767-4f88-a7dc-b920c6d2b4a8',
#       'name': 'Seattle Seahawks',
#       'alias': 'SEA',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4430'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 25,
#       'away_points': 38,
#       'periods': [{'period_type': 'quarter',
#         'id': 'f898820d-d9e7-4332-8789-dbc8c7e23300',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': 'ba71bd51-b211-47e9-90bc-7e5d0002842b',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 9,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'c15bb48a-1b76-45af-812d-62777a6a7747',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': '0bf42f75-0f35-4a88-add0-6a844172f836',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 13,
#         'away_points': 10}]}},
#     {'id': 'd24d9aab-74ce-44b6-960b-7bf905a416c1',
#      'status': 'closed',
#      'reference': '58177',
#      'number': 10,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 76 F, Humidity: 68%, Wind: SSW 5 mph',
#      'sr_id': 'sr:match:21980353',
#      'venue': {'id': '7c11bb2d-4a53-4842-b842-0f1c63ed78e9',
#       'name': 'FedExField',
#       'city': 'Landover',
#       'state': 'MD',
#       'country': 'USA',
#       'zip': '20785',
#       'address': '1600 FedEx Way',
#       'capacity': 82000,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:6652',
#       'location': {'lat': '38.907724', 'lng': '-76.864613'}},
#      'home': {'id': '22052ff7-c065-42ee-bc8f-c4691c50e624',
#       'name': 'Washington Football Team',
#       'alias': 'WAS',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4432'},
#      'away': {'id': '386bdbf9-9eea-4869-bb9a-274b0bc66e80',
#       'name': 'Philadelphia Eagles',
#       'alias': 'PHI',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4428'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 27,
#       'away_points': 17,
#       'periods': [{'period_type': 'quarter',
#         'id': 'b31c5f2f-3ab5-429f-be38-a4c19c9685f3',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '1676d585-68ed-4ebd-ab69-cb722bc77a6f',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '1608bce9-2d6e-4d98-8590-ddf0dd86bb73',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'be7a7701-3c74-4b7a-a1ef-532b452d60ee',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 13,
#         'away_points': 0}]}},
#     {'id': 'd8655663-9853-4425-96e2-b2d7f5cc23db',
#      'status': 'closed',
#      'reference': '58180',
#      'number': 13,
#      'scheduled': '2020-09-13T20:25:00+00:00',
#      'attendance': 0,
#      'utc_offset': -8,
#      'entry_mode': 'INGEST',
#      'weather': 'Hazy Temp: 66 F, Humidity: 68%, Wind: NNW 6 mph',
#      'sr_id': 'sr:match:21980375',
#      'venue': {'id': '24c71dbf-6469-46f1-8165-22005c295c8f',
#       'name': "Levi's Stadium",
#       'city': 'Santa Clara',
#       'state': 'CA',
#       'country': 'USA',
#       'zip': '95054',
#       'address': '4900 Marie P DeBartolo Way',
#       'capacity': 68500,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:15672',
#       'location': {'lat': '37.403000', 'lng': '-121.970000'}},
#      'home': {'id': 'f0e724b0-4cbf-495a-be47-013907608da9',
#       'name': 'San Francisco 49ers',
#       'alias': 'SF',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4389'},
#      'away': {'id': 'de760528-1dc0-416a-a978-b510d20692ff',
#       'name': 'Arizona Cardinals',
#       'alias': 'ARI',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4412'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 20,
#       'away_points': 24,
#       'periods': [{'period_type': 'quarter',
#         'id': 'c056d097-9413-4814-9ecc-506cba0798e5',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 10,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '08d55abc-3e4e-47cf-9231-c20579615e45',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 3,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '45a7a51a-c01f-4f73-9fb9-2fd27a50ee38',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '3013e3de-bb50-4a95-b12d-4a1a16a1a34f',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 14}]}},
#     {'id': 'de740b16-4d86-4a04-afd0-61b3092799e1',
#      'status': 'closed',
#      'reference': '58176',
#      'number': 9,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Partly Cloudy Temp: 70 F, Humidity: 62%, Wind: NW 8 mph',
#      'sr_id': 'sr:match:21980355',
#      'venue': {'id': 'e43310b1-cb82-4df9-8be5-e9b39637031b',
#       'name': 'Gillette Stadium',
#       'city': 'Foxborough',
#       'state': 'MA',
#       'country': 'USA',
#       'zip': '02035',
#       'address': 'One Patriot Place',
#       'capacity': 66829,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:2379',
#       'location': {'lat': '42.090944', 'lng': '-71.264344'}},
#      'home': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#       'name': 'New England Patriots',
#       'alias': 'NE',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4424'},
#      'away': {'id': '4809ecb0-abd3-451d-9c4a-92a90b83ca06',
#       'name': 'Miami Dolphins',
#       'alias': 'MIA',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4287'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 21,
#       'away_points': 11,
#       'periods': [{'period_type': 'quarter',
#         'id': '20a8342f-b8fd-4dc7-93be-969bca39e4c3',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'c70f25f9-6725-4cc5-8b31-d71dfc92b4bf',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'b47ce390-a94f-454e-a8b4-d1ce7a52057f',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'e05cf539-a4d4-4d78-9286-5a4ebb33b457',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 8}]}},
#     {'id': 'e05cf0a5-89ac-4b68-b7fd-aa018b3737e9',
#      'status': 'closed',
#      'reference': '58170',
#      'number': 3,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Partly Cloudy Temp: 76 F, Humidity: 72%, Wind: SSE 5 mph',
#      'sr_id': 'sr:match:21980363',
#      'venue': {'id': 'd54faae0-0314-484f-8604-9d8dd08e1149',
#       'name': 'M&T Bank Stadium',
#       'city': 'Baltimore',
#       'state': 'MD',
#       'country': 'USA',
#       'zip': '21230',
#       'address': '1101 Russell Street',
#       'capacity': 71008,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8169',
#       'location': {'lat': '39.277995', 'lng': '-76.622592'}},
#      'home': {'id': 'ebd87119-b331-4469-9ea6-d51fe3ce2f1c',
#       'name': 'Baltimore Ravens',
#       'alias': 'BAL',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4413'},
#      'away': {'id': 'd5a2eb42-8065-4174-ab79-0a6fa820e35e',
#       'name': 'Cleveland Browns',
#       'alias': 'CLE',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4417'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 38,
#       'away_points': 6,
#       'periods': [{'period_type': 'quarter',
#         'id': '749ff670-8215-4cc6-ab48-6c2c8ae99e5f',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 10,
#         'away_points': 6},
#        {'period_type': 'quarter',
#         'id': 'f0ae26cb-12c4-403e-9482-601557ee9c92',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '1e653935-4f7c-47a3-b0cd-d18c3b118ee6',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'cd020b95-5c9f-45bb-969e-376c96d263de',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 0}]}},
#     {'id': 'ede37e68-ccac-46c9-9331-7d8a710e0cc2',
#      'status': 'closed',
#      'reference': '58173',
#      'number': 6,
#      'scheduled': '2020-09-13T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Controlled Climate Temp: 68 F, Humidity: 70%, Wind:  mph',
#      'sr_id': 'sr:match:21980361',
#      'venue': {'id': '6e3bcf22-277d-4c06-b019-62aded51654f',
#       'name': 'Ford Field',
#       'city': 'Detroit',
#       'state': 'MI',
#       'country': 'USA',
#       'zip': '48226',
#       'address': '2000 Brush Street',
#       'capacity': 65000,
#       'surface': 'artificial',
#       'roof_type': 'dome',
#       'sr_id': 'sr:venue:8181',
#       'location': {'lat': '42.339958', 'lng': '-83.045636'}},
#      'home': {'id': 'c5a59daa-53a7-4de0-851f-fb12be893e9e',
#       'name': 'Detroit Lions',
#       'alias': 'DET',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4419'},
#      'away': {'id': '7b112545-38e6-483c-a55c-96cf6ee49cb8',
#       'name': 'Chicago Bears',
#       'alias': 'CHI',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4391'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 23,
#       'away_points': 27,
#       'periods': [{'period_type': 'quarter',
#         'id': '9b72099d-3a47-4667-8db1-e1b6fd50c2be',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'c15cbfa1-0062-4680-b690-f8215c9304e7',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 10,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'f99b1494-72d5-4d33-90ff-38c0481480de',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 10,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'c70adaf8-1be1-4d80-b21a-c68bfa1abc17',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 21}]}},
#     {'id': 'f6cfdf75-9c42-40f1-99e0-321c6c08ebcc',
#      'status': 'closed',
#      'reference': '58179',
#      'number': 12,
#      'scheduled': '2020-09-13T20:25:00+00:00',
#      'attendance': 0,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'Partly Cloudy Temp: 86 F, Humidity: 70%, Wind: ENE 14 mph',
#      'sr_id': 'sr:match:21980373',
#      'venue': {'id': '3c85d89a-ec66-4983-acd5-1381d6c8673a',
#       'name': 'Caesars Superdome',
#       'city': 'New Orleans',
#       'state': 'LA',
#       'country': 'USA',
#       'zip': '70112',
#       'address': '1500 Sugar Bowl Drive',
#       'capacity': 73208,
#       'surface': 'artificial',
#       'roof_type': 'dome',
#       'sr_id': 'sr:venue:8195',
#       'location': {'lat': '29.950928', 'lng': '-90.080876'}},
#      'home': {'id': '0d855753-ea21-4953-89f9-0e20aff9eb73',
#       'name': 'New Orleans Saints',
#       'alias': 'NO',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4425'},
#      'away': {'id': '4254d319-1bc7-4f81-b4ab-b5e6f3402b69',
#       'name': 'Tampa Bay Buccaneers',
#       'alias': 'TB',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4388'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 34,
#       'away_points': 23,
#       'periods': [{'period_type': 'quarter',
#         'id': '2cf381cf-c1e5-4846-903a-57fdccf7fc01',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '4fda66f3-6539-4870-9a2a-c23c177494b4',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 17,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '3b2508e0-6132-4ca5-a80b-d09d59caaad3',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '968a5206-e001-4093-8a65-5cbb90eaddfc',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 10,
#         'away_points': 6}]}}]},
#   {'id': '786e068a-6bf5-440c-8ed9-fd5c4bc2cecb',
#    'sequence': 2,
#    'title': '2',
#    'games': [{'id': '0848b764-f817-46fa-a06f-2c2ec8e6cc61',
#      'status': 'closed',
#      'reference': '58194',
#      'number': 27,
#      'scheduled': '2020-09-20T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'Sunny Temp: 72 F, Humidity: 60%, Wind: WE 5 mph',
#      'sr_id': 'sr:match:21981055',
#      'venue': {'id': '5295c1b7-c85c-49cb-9569-1707c65324e5',
#       'name': 'Nissan Stadium',
#       'city': 'Nashville',
#       'state': 'TN',
#       'country': 'USA',
#       'zip': '37213',
#       'address': 'One Titans Way',
#       'capacity': 69143,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8207',
#       'location': {'lat': '36.166367', 'lng': '-86.771223'}},
#      'home': {'id': 'd26a1ca5-722d-4274-8f97-c92e49c96315',
#       'name': 'Tennessee Titans',
#       'alias': 'TEN',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:367364'},
#      'away': {'id': 'f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de',
#       'name': 'Jacksonville Jaguars',
#       'alias': 'JAC',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4386'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 33,
#       'away_points': 30,
#       'periods': [{'period_type': 'quarter',
#         'id': '4742350b-e727-4624-9fda-5ba63d993650',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 14,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '26972920-68a8-4ef9-bafe-03549418071a',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 10,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'ade0476f-98d9-4c42-b213-86708daa61b2',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 6,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '0fed0a7b-852a-4595-a158-7021e455602d',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 3,
#         'away_points': 13}]}},
#     {'id': '15246a0c-b492-46aa-a980-a3bfce1eadc3',
#      'status': 'closed',
#      'reference': '58185',
#      'number': 18,
#      'scheduled': '2020-09-20T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'Temp: 66 F, Humidity: 41%, Wind: SE 12 mph',
#      'sr_id': 'sr:match:21980851',
#      'venue': {'id': 'd7866605-5ac6-4b3a-90e8-760cc5a26b75',
#       'name': 'Soldier Field',
#       'city': 'Chicago',
#       'state': 'IL',
#       'country': 'USA',
#       'zip': '60605',
#       'address': '1410 South Museum Campus Drive',
#       'capacity': 61500,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:2109',
#       'location': {'lat': '41.862498', 'lng': '-87.616979'}},
#      'home': {'id': '7b112545-38e6-483c-a55c-96cf6ee49cb8',
#       'name': 'Chicago Bears',
#       'alias': 'CHI',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4391'},
#      'away': {'id': '04aa1c9d-66da-489d-b16a-1dee3f2eec4d',
#       'name': 'New York Giants',
#       'alias': 'NYG',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4426'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 17,
#       'away_points': 13,
#       'periods': [{'period_type': 'quarter',
#         'id': 'df08e57a-f564-4da7-b247-e6ef5238dacf',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 10,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'f0559ab7-f5c9-4ab5-af74-374dc6ff3929',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'e1bb79ff-66fb-49ad-823a-68516bac7b0a',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '15e1925d-3eba-432a-a95f-e89e1ee1609d',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 10}]}},
#     {'id': '1a05d640-79ad-40ad-b0dd-0cc8fd35d371',
#      'status': 'closed',
#      'reference': '58187',
#      'number': 20,
#      'scheduled': '2020-09-20T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'Sunny Temp: 66 F, Humidity: 41%, Wind: South 12 mph',
#      'sr_id': 'sr:match:21980785',
#      'venue': {'id': '5a60dd3a-302c-41c6-ab0f-dd335c1103c2',
#       'name': 'Lambeau Field',
#       'city': 'Green Bay',
#       'state': 'WI',
#       'country': 'USA',
#       'zip': '54304',
#       'address': '1265 Lombardi Avenue',
#       'capacity': 81435,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8183',
#       'location': {'lat': '44.501357', 'lng': '-88.062440'}},
#      'home': {'id': 'a20471b4-a8d9-40c7-95ad-90cc30e46932',
#       'name': 'Green Bay Packers',
#       'alias': 'GB',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4420'},
#      'away': {'id': 'c5a59daa-53a7-4de0-851f-fb12be893e9e',
#       'name': 'Detroit Lions',
#       'alias': 'DET',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4419'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 42,
#       'away_points': 21,
#       'periods': [{'period_type': 'quarter',
#         'id': '8f2bbc93-2f10-4bff-9730-2fa05a3567c7',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': '33ebf551-95b1-4ec8-9114-c52583e5c780',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '2c1ed01d-62c8-44da-a6aa-5baf1918af34',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 17,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'b0849ec6-6ae3-4107-9342-15cdbd64140a',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 8,
#         'away_points': 7}]}},
#     {'id': '2d9aecdb-7ffb-4157-954a-50dbd5ba9f66',
#      'status': 'closed',
#      'reference': '58193',
#      'number': 26,
#      'scheduled': '2020-09-20T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 85 F, Humidity: 72%, Wind: NE 17 mph',
#      'sr_id': 'sr:match:21980909',
#      'venue': {'id': '6fccc39c-80bc-4c81-83d9-2d5a848c8c09',
#       'name': 'Raymond James Stadium',
#       'city': 'Tampa',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '33607',
#       'address': '4201 North Dale Mabry Highway',
#       'capacity': 65890,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8205',
#       'location': {'lat': '27.976211', 'lng': '-82.503625'}},
#      'home': {'id': '4254d319-1bc7-4f81-b4ab-b5e6f3402b69',
#       'name': 'Tampa Bay Buccaneers',
#       'alias': 'TB',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4388'},
#      'away': {'id': 'f14bf5cc-9a82-4a38-bc15-d39f75ed5314',
#       'name': 'Carolina Panthers',
#       'alias': 'CAR',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4415'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 31,
#       'away_points': 17,
#       'periods': [{'period_type': 'quarter',
#         'id': 'fd990612-ab39-46bb-8d93-1c8a104b3c0a',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 14,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '48eb0e3c-ff89-4748-acf9-69cbe80c7be7',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '19b04ecc-fa4c-47db-babb-1b0c349a19fd',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'ef47efdc-615a-4eb2-90a9-443717b97cea',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 10,
#         'away_points': 10}]}},
#     {'id': '3105da72-b6ee-4e37-9cb6-a57a54e6abf0',
#      'status': 'closed',
#      'reference': '58189',
#      'number': 22,
#      'scheduled': '2020-09-20T17:00:00+00:00',
#      'attendance': 11075,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 90 F, Humidity: 68%, Wind: Southeast 5 mph',
#      'sr_id': 'sr:match:21981073',
#      'venue': {'id': '50a5c833-1570-4c38-abc7-7914cf87dbde',
#       'name': 'Hard Rock Stadium',
#       'city': 'Miami Gardens',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '33056',
#       'address': '2269 Northwest 199th Street',
#       'capacity': 65326,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:20269',
#       'location': {'lat': '25.958025', 'lng': '-80.238724'}},
#      'home': {'id': '4809ecb0-abd3-451d-9c4a-92a90b83ca06',
#       'name': 'Miami Dolphins',
#       'alias': 'MIA',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4287'},
#      'away': {'id': '768c92aa-75ff-4a43-bcc0-f2798c2e1724',
#       'name': 'Buffalo Bills',
#       'alias': 'BUF',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4376'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 28,
#       'away_points': 31,
#       'periods': [{'period_type': 'quarter',
#         'id': '5523a1ec-6ec2-4521-ba3d-c3565769678c',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '2fd4a4a8-a3bd-4c0c-8011-47101e20e0dd',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 3,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '746d3fa9-aebe-4460-aca5-d5eef9d754b8',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 3,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '6b56913c-8802-426b-aec0-2b999360edf5',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 15,
#         'away_points': 14}]}},
#     {'id': '3346e48f-481e-4c35-b0fb-1402febaf963',
#      'status': 'closed',
#      'reference': '58190',
#      'number': 23,
#      'scheduled': '2020-09-20T17:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Mostly Sunny Temp: 61 F, Humidity: 29%, Wind: NE 7 mph',
#      'sr_id': 'sr:match:21981079',
#      'venue': {'id': '5d4c85c7-d84e-4e10-bd6a-8a15ebecca5c',
#       'name': 'MetLife Stadium',
#       'city': 'East Rutherford',
#       'state': 'NJ',
#       'country': 'USA',
#       'zip': '07073',
#       'address': 'One MetLife Stadium Drive',
#       'capacity': 82500,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:1981',
#       'location': {'lat': '40.813611', 'lng': '-74.074444'}},
#      'home': {'id': '5fee86ae-74ab-4bdd-8416-42a9dd9964f3',
#       'name': 'New York Jets',
#       'alias': 'NYJ',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4427'},
#      'away': {'id': 'f0e724b0-4cbf-495a-be47-013907608da9',
#       'name': 'San Francisco 49ers',
#       'alias': 'SF',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4389'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 13,
#       'away_points': 31,
#       'periods': [{'period_type': 'quarter',
#         'id': 'f92cc73a-c011-4549-a0fe-8572f3d64608',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '337731c2-4511-4d40-8ea7-63b7a7975a9c',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 0,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': 'bbe53584-80c9-455a-b6ab-094661151499',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 3,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'e562dc6f-f1ec-4aed-b9d5-aed5ef7d0c4d',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 7}]}},
#     {'id': '3bca2cee-37e4-48d8-a3cd-bb77713b2c19',
#      'status': 'closed',
#      'reference': '58196',
#      'number': 29,
#      'scheduled': '2020-09-20T20:25:00+00:00',
#      'attendance': 0,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'Rainy Temp: 70 F, Humidity: 95%, Wind: N 15 MPH mph',
#      'sr_id': 'sr:match:21981003',
#      'venue': {'id': '6a72e5ca-33d0-40af-8e6b-b32a4d3d9346',
#       'name': 'NRG Stadium',
#       'city': 'Houston',
#       'state': 'TX',
#       'country': 'USA',
#       'zip': '77054',
#       'address': 'One Reliant Park',
#       'capacity': 72220,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:2402',
#       'location': {'lat': '29.684735', 'lng': '-95.410725'}},
#      'home': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#       'name': 'Houston Texans',
#       'alias': 'HOU',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4324'},
#      'away': {'id': 'ebd87119-b331-4469-9ea6-d51fe3ce2f1c',
#       'name': 'Baltimore Ravens',
#       'alias': 'BAL',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4413'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 16,
#       'away_points': 33,
#       'periods': [{'period_type': 'quarter',
#         'id': '920a36d2-d24b-420d-9ff4-09ac2fac92ec',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '064e9373-c976-420c-87a3-6d77530f46cb',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 10,
#         'away_points': 17},
#        {'period_type': 'quarter',
#         'id': '5d89056b-672f-4d76-8b78-67b4787d1ad6',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '8f05fc65-9fdb-42e4-a252-f5f80f940a17',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 6,
#         'away_points': 10}]}},
#     {'id': '52633d6e-1bd4-4f6f-b981-ee10f713c99b',
#      'status': 'closed',
#      'reference': '58184',
#      'number': 17,
#      'scheduled': '2020-09-18T00:20:00+00:00',
#      'attendance': 6000,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Dry Temp: 65 F, Humidity: 52%, Wind: NE 8 mph',
#      'sr_id': 'sr:match:21980829',
#      'venue': {'id': '90c38d91-3774-4f5d-82ca-1c806828219f',
#       'name': 'FirstEnergy Stadium',
#       'city': 'Cleveland',
#       'state': 'OH',
#       'country': 'USA',
#       'zip': '44114',
#       'address': '100 Alfred Lerner Way',
#       'capacity': 67895,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8177',
#       'location': {'lat': '41.506054', 'lng': '-81.700004'}},
#      'home': {'id': 'd5a2eb42-8065-4174-ab79-0a6fa820e35e',
#       'name': 'Cleveland Browns',
#       'alias': 'CLE',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4417'},
#      'away': {'id': 'ad4ae08f-d808-42d5-a1e6-e9bc4e34d123',
#       'name': 'Cincinnati Bengals',
#       'alias': 'CIN',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4416'},
#      'broadcast': {'network': 'NFL'},
#      'scoring': {'home_points': 35,
#       'away_points': 30,
#       'periods': [{'period_type': 'quarter',
#         'id': '00ada949-f52c-4006-9cec-4c79e9fc5322',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'ad4e4b2b-cc9e-42d5-a5d8-3e0737f2f173',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '1869b06c-bf9a-4aeb-a1c7-1f9c23a3819a',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '0d685dd5-5de6-4cba-940e-40352b2f3f7f',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 14}]}},
#     {'id': '84bd0796-648c-4e7c-8a4e-59d1bca1b1e3',
#      'status': 'closed',
#      'reference': '58199',
#      'number': 32,
#      'scheduled': '2020-09-22T00:15:00+00:00',
#      'attendance': 0,
#      'utc_offset': -8,
#      'entry_mode': 'INGEST',
#      'weather': 'Sunny Temp: 99 F, Humidity: Wind:',
# ...
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 0}]}},
#     {'id': 'a2730c50-3803-43ea-a9e2-029c4da1dc57',
#      'status': 'closed',
#      'reference': '58422',
#      'number': 255,
#      'scheduled': '2021-01-03T21:25:00+00:00',
#      'attendance': 0,
#      'utc_offset': -8,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 59 F, Humidity: 63%, Wind: S 4 mph',
#      'sr_id': 'sr:match:21980895',
#      'venue': {'id': '790c1f04-73c6-4f6f-8b1e-78a62260be90',
#       'name': 'SoFi Stadium',
#       'city': 'Inglewood',
#       'state': 'CA',
#       'country': 'USA',
#       'zip': '90301',
#       'address': '1000 S Prairie Ave',
#       'capacity': 70240,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:52183',
#       'location': {'lat': '33.953536', 'lng': '-118.338734'}},
#      'home': {'id': '2eff2a03-54d4-46ba-890e-2bc3925548f3',
#       'name': 'Los Angeles Rams',
#       'alias': 'LA',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4387'},
#      'away': {'id': 'de760528-1dc0-416a-a978-b510d20692ff',
#       'name': 'Arizona Cardinals',
#       'alias': 'ARI',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4412'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 18,
#       'away_points': 7,
#       'periods': [{'period_type': 'quarter',
#         'id': '4906ab4d-8862-4e7f-8d4b-80d7870aff61',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'be0ec94a-eba2-48c4-bd67-58669ed658a9',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 12,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '525813ad-20be-461e-8ab5-326e2a7d7a0e',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 3,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'dcef44ca-90b8-4ee0-bd55-61706a93d646',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 3,
#         'away_points': 0}]}},
#     {'id': 'a48c4a31-3b0f-4a83-8ced-32b1f37da95c',
#      'status': 'closed',
#      'reference': '58421',
#      'number': 254,
#      'scheduled': '2021-01-03T21:25:00+00:00',
#      'attendance': 9976,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 36 F, Humidity: 84%, Wind: W 4 mph',
#      'sr_id': 'sr:match:21980781',
#      'venue': {'id': '6ed18563-53e0-46c2-a91d-12d73a16456d',
#       'name': 'Lucas Oil Stadium',
#       'city': 'Indianapolis',
#       'state': 'IN',
#       'country': 'USA',
#       'zip': '46225',
#       'address': '500 South Capitol Avenue',
#       'capacity': 67000,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:8185',
#       'location': {'lat': '39.760008', 'lng': '-86.163906'}},
#      'home': {'id': '82cf9565-6eb9-4f01-bdbd-5aa0d472fcd9',
#       'name': 'Indianapolis Colts',
#       'alias': 'IND',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4421'},
#      'away': {'id': 'f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de',
#       'name': 'Jacksonville Jaguars',
#       'alias': 'JAC',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4386'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 28,
#       'away_points': 14,
#       'periods': [{'period_type': 'quarter',
#         'id': '9870c6ed-179a-4eb9-8baa-0c2749fc531e',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 10,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'dfcd5583-dbe3-4048-b826-ffab61628115',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 10,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '3e9e0e27-afb9-46b0-9697-4a47e4670da4',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'fe1e3fb4-a99f-4931-99cc-07337cda305e',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 8,
#         'away_points': 0}]}},
#     {'id': 'a7896aa5-0678-4820-8ec3-2da46d2d435e',
#      'status': 'closed',
#      'reference': '58420',
#      'number': 253,
#      'scheduled': '2021-01-03T21:25:00+00:00',
#      'attendance': 12504,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'Sunny Temp: 66 F, Humidity: 39%, Wind: SSW 11 mph',
#      'sr_id': 'sr:match:21980615',
#      'venue': {'id': '6a72e5ca-33d0-40af-8e6b-b32a4d3d9346',
#       'name': 'NRG Stadium',
#       'city': 'Houston',
#       'state': 'TX',
#       'country': 'USA',
#       'zip': '77054',
#       'address': 'One Reliant Park',
#       'capacity': 72220,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:2402',
#       'location': {'lat': '29.684735', 'lng': '-95.410725'}},
#      'home': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#       'name': 'Houston Texans',
#       'alias': 'HOU',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4324'},
#      'away': {'id': 'd26a1ca5-722d-4274-8f97-c92e49c96315',
#       'name': 'Tennessee Titans',
#       'alias': 'TEN',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:367364'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 38,
#       'away_points': 41,
#       'periods': [{'period_type': 'quarter',
#         'id': '26a1dca2-d128-4ffa-86bc-6775c1439298',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '16bbb9bf-c3a5-496e-b65b-785d79039adc',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 6,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': '382ea8f6-ee0f-4ef2-b702-93828b993250',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 19,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': '562d2365-7028-4379-9242-03f47f96e90c',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 10,
#         'away_points': 10}]}},
#     {'id': 'b06ff633-dedc-4aae-be06-a359c034e6d1',
#      'status': 'closed',
#      'reference': '58410',
#      'number': 243,
#      'scheduled': '2021-01-03T21:25:00+00:00',
#      'attendance': 0,
#      'utc_offset': -6,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 32 F, Humidity: 85%, Wind: W 7 MPH mph',
#      'sr_id': 'sr:match:21981001',
#      'venue': {'id': 'd7866605-5ac6-4b3a-90e8-760cc5a26b75',
#       'name': 'Soldier Field',
#       'city': 'Chicago',
#       'state': 'IL',
#       'country': 'USA',
#       'zip': '60605',
#       'address': '1410 South Museum Campus Drive',
#       'capacity': 61500,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:2109',
#       'location': {'lat': '41.862498', 'lng': '-87.616979'}},
#      'home': {'id': '7b112545-38e6-483c-a55c-96cf6ee49cb8',
#       'name': 'Chicago Bears',
#       'alias': 'CHI',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4391'},
#      'away': {'id': 'a20471b4-a8d9-40c7-95ad-90cc30e46932',
#       'name': 'Green Bay Packers',
#       'alias': 'GB',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4420'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 16,
#       'away_points': 35,
#       'periods': [{'period_type': 'quarter',
#         'id': '0c8dcb41-e6ab-4ab0-bd00-79610a4843f7',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '4be4903b-233a-43fa-af87-dbb18471b020',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 6,
#         'away_points': 21},
#        {'period_type': 'quarter',
#         'id': 'b97c7f33-0d92-4d87-8891-01f6ad5ce457',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 3,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '16ab1bd5-7bed-4733-8177-059cea4ae3c8',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 14}]}},
#     {'id': 'b870d8b0-84cf-4d58-bb5f-42784958df87',
#      'status': 'closed',
#      'reference': '58417',
#      'number': 250,
#      'scheduled': '2021-01-04T01:20:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Rain Temp: 38 F, Humidity: 92%, Wind: N 10 mph',
#      'sr_id': 'sr:match:21980793',
#      'venue': {'id': '4fa8c29c-6626-464c-8540-314ed7535e1b',
#       'name': 'Lincoln Financial Field',
#       'city': 'Philadelphia',
#       'state': 'PA',
#       'country': 'USA',
#       'zip': '19148',
#       'address': '1020 Pattison Avenue',
#       'capacity': 69596,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:1833',
#       'location': {'lat': '39.900872', 'lng': '-75.167311'}},
#      'home': {'id': '386bdbf9-9eea-4869-bb9a-274b0bc66e80',
#       'name': 'Philadelphia Eagles',
#       'alias': 'PHI',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4428'},
#      'away': {'id': '22052ff7-c065-42ee-bc8f-c4691c50e624',
#       'name': 'Washington Football Team',
#       'alias': 'WAS',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4432'},
#      'broadcast': {'network': 'NBC'},
#      'scoring': {'home_points': 14,
#       'away_points': 20,
#       'periods': [{'period_type': 'quarter',
#         'id': '0724a5cf-fbbd-4553-87ea-c0c230a956b7',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '2b78c360-eec9-46cd-9db4-a8c1e4201076',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '9984d7a2-a3a2-489f-bf5d-63163aa8c8ea',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '1b3f0251-0af1-47c3-b05d-e97b9a5d8540',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 3}]}},
#     {'id': 'ec4d4be2-01e5-4465-956b-8309c9ea3e8d',
#      'status': 'closed',
#      'reference': '58416',
#      'number': 249,
#      'scheduled': '2021-01-03T18:00:00+00:00',
#      'attendance': 0,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Overcast Temp: 33 F, Humidity: 85%, Wind: NE 6 mph',
#      'sr_id': 'sr:match:21980765',
#      'venue': {'id': '5d4c85c7-d84e-4e10-bd6a-8a15ebecca5c',
#       'name': 'MetLife Stadium',
#       'city': 'East Rutherford',
#       'state': 'NJ',
#       'country': 'USA',
#       'zip': '07073',
#       'address': 'One MetLife Stadium Drive',
#       'capacity': 82500,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:1981',
#       'location': {'lat': '40.813611', 'lng': '-74.074444'}},
#      'home': {'id': '04aa1c9d-66da-489d-b16a-1dee3f2eec4d',
#       'name': 'New York Giants',
#       'alias': 'NYG',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4426'},
#      'away': {'id': 'e627eec7-bbae-4fa4-8e73-8e1d6bc5c060',
#       'name': 'Dallas Cowboys',
#       'alias': 'DAL',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4392'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 23,
#       'away_points': 19,
#       'periods': [{'period_type': 'quarter',
#         'id': '6d191438-cd37-4de9-9c42-d763cee67f41',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 6,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'c6371857-59ca-4974-b085-12aa728b0fb4',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 6},
#        {'period_type': 'quarter',
#         'id': '0eda4fed-59f1-4f0f-9d99-867e59558b00',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '4b16b163-765a-4c56-a6e1-b8bdb7b439ec',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 3,
#         'away_points': 3}]}},
#     {'id': 'f6f38d07-d146-4cfe-8b43-56dee121729d',
#      'status': 'closed',
#      'reference': '58409',
#      'number': 242,
#      'scheduled': '2021-01-03T21:25:00+00:00',
#      'attendance': 1500,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 57 F, Humidity: 80%, Wind: ENE 2 mph',
#      'sr_id': 'sr:match:21981047',
#      'venue': {'id': '39be9ed4-3292-49ac-8699-a381de3a4969',
#       'name': 'Bank of America Stadium',
#       'city': 'Charlotte',
#       'state': 'NC',
#       'country': 'USA',
#       'zip': '28202',
#       'address': '800 South Mint Street',
#       'capacity': 75419,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8173',
#       'location': {'lat': '35.225937', 'lng': '-80.853133'}},
#      'home': {'id': 'f14bf5cc-9a82-4a38-bc15-d39f75ed5314',
#       'name': 'Carolina Panthers',
#       'alias': 'CAR',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4415'},
#      'away': {'id': '0d855753-ea21-4953-89f9-0e20aff9eb73',
#       'name': 'New Orleans Saints',
#       'alias': 'NO',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4425'},
#      'broadcast': {'network': 'FOX'},
#      'scoring': {'home_points': 7,
#       'away_points': 33,
#       'periods': [{'period_type': 'quarter',
#         'id': 'fffac552-7597-422a-a11b-8e8aa99a1e51',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'aa6a5281-63fa-4aed-94ae-4f13d713f68d',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 0,
#         'away_points': 9},
#        {'period_type': 'quarter',
#         'id': '53bfaf6c-6c12-4782-83cf-362190bac2f6',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '1990a512-7b7f-4de2-adf9-0e56dd0ca1e6',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 7}]}},
#     {'id': 'ffefae13-6fa5-4699-960f-0a7fd3c1265d',
#      'status': 'closed',
#      'reference': '58412',
#      'number': 245,
#      'scheduled': '2021-01-03T18:00:00+00:00',
#      'attendance': 11989,
#      'utc_offset': -5,
#      'entry_mode': 'INGEST',
#      'weather': 'Cloudy Temp: 38 F, Humidity: 91%, Wind: West 7 mph',
#      'sr_id': 'sr:match:21980651',
#      'venue': {'id': '90c38d91-3774-4f5d-82ca-1c806828219f',
#       'name': 'FirstEnergy Stadium',
#       'city': 'Cleveland',
#       'state': 'OH',
#       'country': 'USA',
#       'zip': '44114',
#       'address': '100 Alfred Lerner Way',
#       'capacity': 67895,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8177',
#       'location': {'lat': '41.506054', 'lng': '-81.700004'}},
#      'home': {'id': 'd5a2eb42-8065-4174-ab79-0a6fa820e35e',
#       'name': 'Cleveland Browns',
#       'alias': 'CLE',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4417'},
#      'away': {'id': 'cb2f9f1f-ac67-424e-9e72-1475cb0ed398',
#       'name': 'Pittsburgh Steelers',
#       'alias': 'PIT',
#       'game_number': 16,
#       'sr_id': 'sr:competitor:4345'},
#      'broadcast': {'network': 'CBS'},
#      'scoring': {'home_points': 24,
#       'away_points': 22,
#       'periods': [{'period_type': 'quarter',
#         'id': '0dec3e50-8a62-4b96-9706-d493371955df',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'ac15d067-336d-4b8c-bb41-306d186062f1',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 3,
#         'away_points': 6},
#        {'period_type': 'quarter',
#         'id': '17f45032-46c9-413b-acbf-cf34eb640dde',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '55bd1f4f-48d6-47f5-9b75-76d4b2808c1c',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 13}]}}]}],
#  '_comment': 'Generation started @ 2021-08-14 21:00:39 UTC ended @ 2021-08-14 21:00:39 UTC'}

# %%
# pull unique game_id from 2020 schedule
all_games = []
for i, item in sch['weeks'].iteritems():
    games = item['games']
    for n in range(len(games)):
        all_games.append(games[n])
    
all_games_info = pd.DataFrame(all_games)

all_games_info = all_games_info.loc[:, 'id']
all_games_id = list(all_games_info)

# %%
# add private api_key
# loop through all_games_id to get data from each game in 2020 season
api_key = api_key
conn = http.client.HTTPSConnection("api.sportradar.us")
game_data = []
for n, game in enumerate(all_games_id):
    if n % 10 == 0:
        print(f'Completed {n} games')
        
    conn.request("GET", f"/nfl/official/trial/v6/en/games/{game}/pbp.json?api_key={api_key}")
    res = conn.getresponse()
    
    data = res.read()
    game_data.append(data)
# Out:
# Completed 0 games
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-76b345856445> in <module>
#       7
#       8     conn.request("GET", f"/nfl/official/trial/v6/en/games/{game}/pbp.json?api_key={api_key}")
# ----> 9     res = conn.getresponse()
#      10
#      11     data = res.read()
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# byte data shorter than 10k is not full game
# either postponed or no game data
list_data = [d for d in game_data if len(d) > 10000]

# %%
def get_plays(data):
    '''
    Input - data: json api data from sportradar
    
    Output - cleaned df of qb stats from game
    '''
    
    obj = json.loads(data)
    df = pd.json_normalize(obj, record_path=['periods'],
                           meta=[['summary', 'season', 'year']], errors='ignore')
    season = df['summary.season.year'][0]

    q1 = pd.json_normalize(df['pbp'][0])
    q1['quarter'] = 1
    q2 = pd.json_normalize(df['pbp'][1])
    q2['quarter'] = 2
    q3 = pd.json_normalize(df['pbp'][2])
    q3['quarter'] = 3
    q4 = pd.json_normalize(df['pbp'][3])
    q4['quarter'] = 4
    quarters = [q1, q2, q3, q4]

    drives = pd.concat(quarters, ignore_index=True)
    drives = drives.loc[drives['type'] == 'drive']

    plays = []
    quarts = {1:[], 2:[], 3:[], 4:[]}

    for i, row in drives.iterrows():
        drive_id = row['events'][0]['id']
        quarter = row['quarter']
        quarts[quarter].append(drive_id)
        play = row['events']
        for n in play:
            plays.append(n)

    passing_areas = ['Flat', 'Underneath Screen', 'WR Screen',
                     'Comeback', 'Curl', 'Cross', 'Go', 'Slant', 'Out']
    non_play_event = ['period_end', 'timeout', 'game_over']

    plays = pd.DataFrame(plays)

    for k,v in quarts.items():
        for i, row in plays.iterrows():
            if row['id'] in v:
                plays.loc[i, 'quarter'] = k
    plays['quarter'].fillna(method='ffill', inplace=True)

    pass_plays = plays.loc[(plays['play_type'] == 'pass') & 
                           (plays['pass_route'].isin(passing_areas)) &
                           ~(plays['event_type'].isin(non_play_event))]
    pass_plays.reset_index(inplace=True, drop=True)

    passing_stats = []
    for i, item in pass_plays['statistics'].iteritems():
        stats = pd.Series(item[0])
        passing_stats.append(stats)


    passing_details = []
    for i, item in pass_plays['details'].iteritems():
        details = pd.Series(item[0])
        passing_details.append(details)

    down_info = []
    for i, row in pass_plays.iterrows():
        c = row['clock']
        q = row['quarter']
        d = row['start_situation']['down']
        y = row['start_situation']['yfd']
        down_info.append((c,q,d,y))


    df = pd.DataFrame(passing_stats)
    dfi = pd.DataFrame(passing_details)
    dfii = pd.DataFrame(down_info, 
                        columns=['clock', 'quarter', 'down', 'yards_to_first'])

    df = pd.concat([df,dfi,dfii], axis=1)

    # additional data in pass_plays
    additional_columns = ['hash_mark', 'play_action', 'run_pass_option', 'blitz',
                          'qb_at_snap', 'players_rushed', 'pocket_location', 'pass_route']

    df = df.merge(pass_plays[additional_columns], left_index=True, right_index=True)
    df['season'] = season
#     df['quarter'] = df['quarter'].astype('int')
    df = df.loc[df['stat_type'] == 'pass']

    names = []
    teams = []
    for i, row in df.iterrows():

        name = row['player']['name']
        names.append(name)
        team = row['team']['alias']
        teams.append(team)
    df['name'] = names
    df['team'] = teams

    dropping = ['player', 'description', 'players',
                'stat_type', 'attempt', 'category'] 
    df.drop(columns=dropping, inplace=True)
    df = df.loc[:, ~df.columns.duplicated()]

    name_col = df.pop('name')
    team_col = df.pop('team')
    df.insert(0, 'name', name_col)
    df.insert(1, 'team', team_col)

    return df

# %%
# list_data = games actually played, does not include postponed/cancelled games (covid-19)

all_dfs = []
for n, game in enumerate(list_data):
    if n % 20 == 0:
        print(f'Completed {n+1} games')
    p = get_plays(game)
    all_dfs.append(p)

# %%
# creating df combining all 2020 game data
df = pd.concat(all_dfs, ignore_index=True)
df.shape

# %%
# export df to csv
df.to_csv('./Data/all_dfs.csv')
